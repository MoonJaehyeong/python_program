# %% [markdown]
# <a href="https://colab.research.google.com/github/MoonJaehyeong/python_program/blob/main/7%EC%A3%BC%EC%B0%A8_%EC%88%99%EC%A0%9C3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 이름: 문재형
# 학번: 2022177357

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# 파일위치: '/content/gdrive/My Drive/Colab Notebooks/python_program/TopSellingAlbums.csv'

# %%
import pandas as pd # pd라는 이름으로 pandas import

# %%
# data라는 dict 정의
data = {'Name':['Tom', 'nick', 'krish', 'jack'],
        'Age':[20, 21, 19, 18]}

# DataFrame method 사용
df = pd.DataFrame(data)

print(df)
# Out:
#     Name  Age
# 0    Tom   20
# 1   nick   21
# 2  krish   19
# 3   jack   18

# %%
type(data)
# Out:
# dict

# %%
csv_path = '/content/gdrive/My Drive/Colab Notebooks/python_program/TopSellingAlbums.csv'
df = pd.read_csv(csv_path) # pandas를 통해 해당 파일을 읽은 값이 df로 정의한다.

# %%
df.tail() # df의 tail 값 호출(하단 5개)
# Out:
#             Artist                            Album  Released   Length  \
# 3  Whitney Houston                    The Bodyguard      1992  0:57:44
# 4        Meat Loaf                  Bat Out of Hell      1977  0:46:33
# 5           Eagles  Their Greatest Hits (1971-1975)      1976  0:43:08
# 6         Bee Gees             Saturday Night Fever      1977  1:15:54
# 7    Fleetwood Mac                          Rumours      1977  0:40:01
#
#                          Genre  Music Recording Sales (millions)  \
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
# 5   rock, soft rock, folk rock                              32.2
# 6                        disco                              20.6
# 7                    soft rock                              27.9
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 3                        44  17-Nov-92          Y     8.5
# ...

# %%
xlsx_path = '/content/gdrive/My Drive/Colab Notebooks/python_program/TopSellingAlbums.xlsx'
df1 = pd.read_excel(xlsx_path)
df1.head()
# Out:
#             Artist                      Album  Released    Length  \
# 0  Michael Jackson                   Thriller      1982  00:42:19
# 1            AC/DC              Back in Black      1980  00:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  00:42:49
# 3  Whitney Houston              The Bodyguard      1992  00:57:44
# 4        Meat Loaf            Bat Out of Hell      1977  00:46:33
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 0                        65 1982-11-30        NaN    10.0
# 1                        50 1980-07-25        NaN     9.5
# ...

# %%
x = df[['Genre']] #df의 Genre 열 호출,,, [[]]와 []는 정확히 뭔 차이?
x
# Out:
#                          Genre
# 0               pop, rock, R&B
# 1                    hard rock
# 2             progressive rock
# 3               R&B, soul, pop
# 4  hard rock, progressive rock
# 5   rock, soft rock, folk rock
# 6                        disco
# 7                    soft rock

# %%
x = df['Genre'] # [[]]와 []는 정확히 뭔 차이?
x
# Out:
# 0                 pop, rock, R&B
# 1                      hard rock
# 2               progressive rock
# 3                 R&B, soul, pop
# 4    hard rock, progressive rock
# 5     rock, soft rock, folk rock
# 6                          disco
# 7                      soft rock
# Name: Genre, dtype: object

# %%
x = df['Length']
x
# Out:
# 0    0:42:19
# 1    0:42:11
# 2    0:42:49
# 3    0:57:44
# 4    0:46:33
# 5    0:43:08
# 6    1:15:54
# 7    0:40:01
# Name: Length, dtype: object

# %%
x = df[['Length']]
x
# Out:
#     Length
# 0  0:42:19
# 1  0:42:11
# 2  0:42:49
# 3  0:57:44
# 4  0:46:33
# 5  0:43:08
# 6  1:15:54
# 7  0:40:01

# %%
y = df[['Artist','Length','Genre']]
y
# Out:
#             Artist   Length                        Genre
# 0  Michael Jackson  0:42:19               pop, rock, R&B
# 1            AC/DC  0:42:11                    hard rock
# 2       Pink Floyd  0:42:49             progressive rock
# 3  Whitney Houston  0:57:44               R&B, soul, pop
# 4        Meat Loaf  0:46:33  hard rock, progressive rock
# 5           Eagles  0:43:08   rock, soft rock, folk rock
# 6         Bee Gees  1:15:54                        disco
# 7    Fleetwood Mac  0:40:01                    soft rock

# %%
df.iloc[0, 0] # 첫번째 행-첫번째 열 값 호출
# Out:
# 'Michael Jackson'

# %%
df.iloc[[0, 0]] #여기서 ,는 and..... 열 자리수 의
# Out:
#             Artist     Album  Released   Length           Genre  \
# 0  Michael Jackson  Thriller      1982  0:42:19  pop, rock, R&B
# 0  Michael Jackson  Thriller      1982  0:42:19  pop, rock, R&B
#
#    Music Recording Sales (millions)  Claimed Sales (millions) Released.1  \
# 0                              46.0                        65  30-Nov-82
# 0                              46.0                        65  30-Nov-82
#
#   Soundtrack  Rating
# 0        NaN    10.0
# 0        NaN    10.0

# %%
df.iloc[1,0]
# Out:
# 'AC/DC'

# %%
df.iloc[[1,0]]
# Out:
#             Artist          Album  Released   Length           Genre  \
# 1            AC/DC  Back in Black      1980  0:42:11       hard rock
# 0  Michael Jackson       Thriller      1982  0:42:19  pop, rock, R&B
#
#    Music Recording Sales (millions)  Claimed Sales (millions) Released.1  \
# 1                              26.1                        50  25-Jul-80
# 0                              46.0                        65  30-Nov-82
#
#   Soundtrack  Rating
# 1        NaN     9.5
# 0        NaN    10.0

# %%
df.loc[0, 'Artist'] #0번째 행의 Artist 열 값은?
# Out:
# 'Michael Jackson'

# %%
df.loc[0, 'Released'] #0번째 행의 Released 열 값은?
# Out:
# 1982

# %%
df.iloc[0:2, 0:3] #첫번째 행부터 1번째 열까지,, 첫번째 열부터 두번째 열까지
# Out:
#             Artist          Album  Released
# 0  Michael Jackson       Thriller      1982
# 1            AC/DC  Back in Black      1980

# %%
df.loc[0:2, 'Artist':'Released']
# Out:
#             Artist                      Album  Released
# 0  Michael Jackson                   Thriller      1982
# 1            AC/DC              Back in Black      1980
# 2       Pink Floyd  The Dark Side of the Moon      1973

# %%
for i, j in df.iterrows():
    print(i, j)
    print()
# Out:
# 0 Artist                              Michael Jackson
# Album                                      Thriller
# Released                                       1982
# Length                                      0:42:19
# Genre                                pop, rock, R&B
# Music Recording Sales (millions)               46.0
# Claimed Sales (millions)                         65
# Released.1                                30-Nov-82
# Soundtrack                                      NaN
# Rating                                         10.0
# Name: 0, dtype: object
#
# 1 Artist                                      AC/DC
# Album                               Back in Black
# Released                                     1980
# Length                                    0:42:11
# Genre                                   hard rock
# Music Recording Sales (millions)             26.1
# Claimed Sales (millions)                       50
# Released.1                              25-Jul-80
# ...

# %%
filter2 = df["Claimed Sales (millions)"]>40

# %%
df.where(filter2)
# Out:
#             Artist                            Album  Released   Length  \
# 0  Michael Jackson                         Thriller    1982.0  0:42:19
# 1            AC/DC                    Back in Black    1980.0  0:42:11
# 2       Pink Floyd        The Dark Side of the Moon    1973.0  0:42:49
# 3  Whitney Houston                    The Bodyguard    1992.0  0:57:44
# 4        Meat Loaf                  Bat Out of Hell    1977.0  0:46:33
# 5           Eagles  Their Greatest Hits (1971-1975)    1976.0  0:43:08
# 6              NaN                              NaN       NaN      NaN
# 7              NaN                              NaN       NaN      NaN
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# ...

# %%
Qz1

# %%
q = df[['Rating']]
q
# Out:
#    Rating
# 0    10.0
# 1     9.5
# 2     9.0
# 3     8.5
# 4     8.0
# 5     7.5
# 6     7.0
# 7     6.5

# %%
Qz2

# %%
q = df[['Released', 'Artist']]
q
# Out:
#    Released           Artist
# 0      1982  Michael Jackson
# 1      1980            AC/DC
# 2      1973       Pink Floyd
# 3      1992  Whitney Houston
# 4      1977        Meat Loaf
# 5      1976           Eagles
# 6      1977         Bee Gees
# 7      1977    Fleetwood Mac

# %%
df.iloc[1, 2]
# Out:
# 1980
